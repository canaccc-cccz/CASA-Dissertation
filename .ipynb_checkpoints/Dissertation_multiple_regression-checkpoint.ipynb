# %%
#import library
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

pd.set_option('display.max_rows', 300) # specifies number of rows to show
pd.options.display.float_format = '{:40,.4f}'.format # specifies default number format to 4 decimal places
plt.style.use('ggplot') # specifies that graphs should use ggplot styling
# %matplotlib inline

# %%
#import data
raw_data=pd.read_csv('summary_regression_data1.csv')
raw_data.head(5)
# Out:
#               area_name  area_code                     total_cases_thousand  \
# 0  Barking and Dagenham  E09000002                                  26.6530
# 1                Barnet  E09000003                                  37.7060
# 2                Bexley  E09000004                                  26.9520
# 3                 Brent  E09000005                                  34.7650
# 4               Bromley  E09000006                                  30.6630
#
#              cases_density(Number per km2)  \
# 0                                 738.3100
# 1                                 434.9000
# 2                                 444.7500
# 3                                 804.7500
# 4                                 204.2800
#
#                            infectious_rate  \
# 0                                   0.1200
# 1                                   0.0900
# 2                                   0.1100
# 3                                   0.1000
# 4                                   0.0900
#
#                   small_businesses_density  \
# 0                                   0.2200
# 1                                   0.3000
# 2                                   0.1600
# 3                                   0.3900
# 4                                   0.1100
#
#                median_income_2012_thousand  \
# 0                                  20.1000
# 1                                  29.5000
# 2                                  25.5000
# 3                                  24.3000
# 4                                  29.6000
#
#                Population_density_thousand  \
# 0                                   6.0500
# 1                                   4.7000
# 2                                   4.2100
# 3                                   7.9600
# 4                                   2.2400
#
#    Proportion_of_population_of_working-age,_2015  \
# 0                                        63.1000
# 1                                        64.9000
# 2                                        62.9000
# 3                                        67.8000
# 4                                        62.6000
#
#                       Employment_rate_2020  Average_house_price_2020_thousand  \
# 0                                  83.9000                                301
# 1                                  90.8000                                524
# 2                                  79.5000                                341
# 3                                  85.6000                                477
# 4                                  88.2000                                434
#
#                        population_thousand  \
# 0                                 218.3700
# 1                                 407.1500
# 2                                 254.9700
# 3                                 343.8500
# 4                                 336.4000
#
#        small_business_number_2020_thousand
# 0                                   8.1000
# 1                                  25.8000
# 2                                   9.8000
# 3                                  17.0000
# 4                                  16.7000

# %%
raw_data.columns
# Out:
# Index(['area_name', 'area_code', 'total_cases_thousand',
#        'cases_density(Number per km2)', 'infectious_rate',
#        'small_businesses_density', 'median_income_2012_thousand',
#        'Population_density_thousand',
#        'Proportion_of_population_of_working-age,_2015', 'Employment_rate_2020',
#        'Average_house_price_2020_thousand', 'population_thousand',
#        'small_business_number_2020_thousand'],
#       dtype='object')

# %%
# raw_data=raw_data.rename(columns={' total_cases ':'total_cases',' cases_proportion ':'cases_proportion',' small_business_number_2020_thousand ':'small_business_number_2020_thousand'})
# raw_data.columns

# %%
raw_data.describe()
# Out:
#                           total_cases_thousand  \
# count                                  32.0000
# mean                                   28.0272
# std                                     7.6992
# min                                    12.3290
# 25%                                    20.5535
# 50%                                    29.0420
# 75%                                    33.6362
# max                                    41.1710
#
#                  cases_density(Number per km2)  \
# count                                  32.0000
# mean                                  747.3209
# std                                   377.2795
# min                                   204.2800
# 25%                                   444.2175
# 50%                                   713.7850
# 75%                                   936.9700
# max                                 1,831.5200
#
#                                infectious_rate  \
# count                                  32.0000
# mean                                    0.0962
# std                                     0.0131
# min                                     0.0700
# 25%                                     0.0900
# 50%                                     0.0950
# 75%                                     0.1025
# max                                     0.1200
#
#                       small_businesses_density  \
# count                                  32.0000
# mean                                    0.5863
# std                                     0.6280
# min                                     0.1000
# 25%                                     0.2425
# 50%                                     0.3250
# 75%                                     0.5950
# max                                     2.6600
#
#                    median_income_2012_thousand  \
# count                                  32.0000
# mean                                   27.4844
# std                                     4.2376
# min                                    18.0000
# 25%                                    24.9500
# 50%                                    26.8500
# 75%                                    29.8500
# max                                    37.0000
#
#                    Population_density_thousand  \
# count                                  32.0000
# mean                                    7.8719
# std                                     4.0635
# min                                     2.2400
# 25%                                     4.7900
# 50%                                     6.3500
# 75%                                    11.4800
# max                                    16.5700
#
#        Proportion_of_population_of_working-age,_2015  \
# count                                        32.0000
# mean                                         68.1188
# std                                           3.8925
# min                                          62.3000
# 25%                                          64.8000
# 50%                                          67.6500
# 75%                                          71.3250
# max                                          75.3000
#
#                           Employment_rate_2020  \
# count                                  32.0000
# mean                                   89.3250
# std                                     4.1747
# min                                    79.0000
# 25%                                    87.6500
# 50%                                    89.5500
# 75%                                    91.8250
# max                                    96.5000
#
#              Average_house_price_2020_thousand  \
# count                                  32.0000
# mean                                  528.9062
# std                                   207.6724
# min                                   301.0000
# 25%                                   403.2500
# 50%                                   465.5000
# 75%                                   566.5000
# max                                 1,319.0000
#
#                            population_thousand  \
# count                                  32.0000
# mean                                  287.6034
# std                                    63.1906
# min                                   160.7900
# 25%                                   251.9350
# 50%                                   291.2450
# 75%                                   333.6475
# max                                   407.1500
#
#            small_business_number_2020_thousand
# count                                  32.0000
# mean                                   18.0625
# std                                    10.6325
# min                                     8.1000
# 25%                                    12.7000
# 50%                                    15.5500
# 75%                                    18.5500
# max                                    57.1000

# %%
#raw_data.to_csv('summary_regression_data.csv')

# %%
# #small_businesses_density ~ cases_density_number_per_km2 + population_density_thousand +
#     employment_rate_2020 +
#     average_house_price_2020_thousand

# %%
# df=raw_data.drop(['date','new_cases','area_name','area_code','small_businesses_food_thousand','Square_Kilometres','small_business_number_2020_thousand'],axis=1)
# df.info()

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   area_name                                      32 non-null     object
#  1   area_code                                      32 non-null     object
#  2   total_cases_thousand                           32 non-null     float64
#  3   cases_density(Number per km2)                  32 non-null     float64
#  4   infectious_rate                                32 non-null     float64
#  5   small_businesses_density                       32 non-null     float64
#  6   median_income_2012_thousand                    32 non-null     float64
#  7   Population_density_thousand                    32 non-null     float64
#  8   Proportion_of_population_of_working-age,_2015  32 non-null     float64
#  9   Employment_rate_2020                           32 non-null     float64
#  10  Average_house_price_2020_thousand              32 non-null     int64
#  11  population_thousand                            32 non-null     float64
#  12  small_business_number_2020_thousand            32 non-null     float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 3.4+ KB

# %%
df=pd.DataFrame(raw_data)

# %%
df['Average_house_price_2020_thousand'] = df['Average_house_price_2020_thousand'].astype(float)
df['total_cases_thousand']=df['total_cases_thousand'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   area_name                                      32 non-null     object
#  1   area_code                                      32 non-null     object
#  2   total_cases_thousand                           32 non-null     float64
#  3   cases_density(Number per km2)                  32 non-null     float64
#  4   infectious_rate                                32 non-null     float64
#  5   small_businesses_density                       32 non-null     float64
#  6   median_income_2012_thousand                    32 non-null     float64
#  7   Population_density_thousand                    32 non-null     float64
#  8   Proportion_of_population_of_working-age,_2015  32 non-null     float64
#  9   Employment_rate_2020                           32 non-null     float64
#  10  Average_house_price_2020_thousand              32 non-null     float64
#  11  population_thousand                            32 non-null     float64
#  12  small_business_number_2020_thousand            32 non-null     float64
# dtypes: float64(11), object(2)
# memory usage: 3.4+ KB

# %%
#assign predictor variables and response variable
predictors_df = df.drop(columns=['small_business_number_2020_thousand','area_code','total_cases_thousand','infectious_rate','Population_density_thousand','small_businesses_density','area_name'], axis=1)
response_df = df[['small_businesses_density']]

# %%
predictors_df.columns
# Out:
# Index(['cases_density(Number per km2)', 'median_income_2012_thousand',
#        'Proportion_of_population_of_working-age,_2015', 'Employment_rate_2020',
#        'Average_house_price_2020_thousand', 'population_thousand'],
#       dtype='object')

# %%
#process VIF to calculate multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from statsmodels.tools.tools import add_constant

def calculate_vif_(df, thresh=10):
    '''
    Calculates VIF each feature in a pandas dataframe
    A constant must be added to variance_inflation_factor or the results will be incorrect

    :param df: the pandas dataframe containing only the predictor features, not the response variable
    :param thresh: the max VIF value before the feature is removed from the dataframe
    :return: dataframe with features removed
    '''
    const = add_constant(df)
    cols = const.columns
    variables = np.arange(const.shape[1])
    vif_df = pd.Series([variance_inflation_factor(const.values, i) 
               for i in range(const.shape[1])], 
              index=const.columns).to_frame()

    vif_df = vif_df.sort_values(by=0, ascending=False).rename(columns={0: 'VIF'})
    vif_df = vif_df.drop('const')
    vif_df = vif_df[vif_df['VIF'] > thresh]

    print('Features above VIF threshold:\n')
    print(vif_df[vif_df['VIF'] > thresh])

    col_to_drop = list(vif_df.index)

    for i in col_to_drop:
        print('Dropping: {}'.format(i))
        df = df.drop(columns=i)

    return df

# %%
df_predictors_select_VIF = calculate_vif_(predictors_df)
print("The columns remaining after VIF selection are:")
print(df_predictors_select_VIF.columns)
# Out:
# Features above VIF threshold:
#
# Empty DataFrame
# Columns: [VIF]
# Index: []
# The columns remaining after VIF selection are:
# Index(['cases_density(Number per km2)', 'median_income_2012_thousand',
#        'Proportion_of_population_of_working-age,_2015', 'Employment_rate_2020',
#        'Average_house_price_2020_thousand', 'population_thousand'],
#       dtype='object')

# %%
regressor_OLS = sm.OLS(endog=response_df, exog=sm.add_constant(df_predictors_select_VIF)).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     small_businesses_density   R-squared:                       0.719
# Model:                                  OLS   Adj. R-squared:                  0.652
# Method:                       Least Squares   F-statistic:                     10.67
# Date:                      Tue, 07 Sep 2021   Prob (F-statistic):           6.86e-06
# Time:                              17:31:45   Log-Likelihood:                -9.6956
# No. Observations:                        32   AIC:                             33.39
# Df Residuals:                            25   BIC:                             43.65
# Df Model:                                 6
# Covariance Type:                  nonrobust
# =================================================================================================================
#                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# const                                            -1.0439      2.345     -0.445      0.660      -5.873       3.785
# cases_density(Number per km2)                     0.0004      0.000      0.822      0.419      -0.001       0.001
# median_income_2012_thousand                       0.0089      0.031      0.290      0.774      -0.054       0.072
# Proportion_of_population_of_working-age,_2015     0.0536      0.043      1.257      0.220      -0.034       0.141
# Employment_rate_2020                             -0.0436      0.023     -1.900      0.069      -0.091       0.004
# Average_house_price_2020_thousand                 0.0020      0.001      2.830      0.009       0.001       0.003
# population_thousand                               0.0011      0.001      0.882      0.386      -0.001       0.004
# ==============================================================================
# Omnibus:                       15.805   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.668
# Skew:                           1.252   Prob(JB):                     3.25e-05
# Kurtosis:                       6.038   Cond. No.                     3.67e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.67e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
